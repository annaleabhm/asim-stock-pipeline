# %% [markdown]
# <p>Testing the SciPy library and Pearson correlation</p>

# %%
# importing libraries
import scipy
import numpy as np
import pandas as pd

# %%
# importing the data
file_path = "./data/"

ohlc = pd.read_csv(f"{file_path}agg_ohlc.csv")

wrds = pd.read_csv(f"{file_path}wrds_quarterly_ratios.csv")

compustat = pd.read_csv(f"{file_path}compustat_quarterly.csv")

# %%
ohlc.merge(compustat, left_on = 'cusip', right_on = 'cusip')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18708\460762254.py in <module>
# ----> 1 ohlc.merge(compustat, left_on = 'cusip', right_on = 'cusip')
#
# c:\Users\annal\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# c:\Users\annal\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ...

# %%
# Cutting off last character/digit from cusip in ohlc
ohlc['ppln_cusip'] = ohlc['cusip'].apply(lambda single_cusip:single_cusip[:-1])

# %%
ohlc.head(4)
# Out:
#    index    datadate  prcod  prchd  prcld  prccd      cusip ppln_cusip
# 0      0  2004-09-01   2.12   2.57   1.93   2.55  665575106   66557510
# 1      1  2004-10-01   2.55   2.95   2.50   2.69  665575106   66557510
# 2      2  2004-11-01   2.68   3.10   2.49   2.91  665575106   66557510
# 3      3  2004-12-01   2.91   3.00   2.60   2.91  665575106   66557510

# %%
# Cutting off last character/digit from cusip in compustat
compustat['ppln_cusip'] = compustat['cusip'].apply(lambda single_cusip:single_cusip[:-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18708\709498641.py in <module>
#       1 # Cutting off last character/digit from cusip in compustat
# ----> 2 compustat['ppln_cusip'] = compustat['cusip'].apply(lambda single_cusip:single_cusip[:-1])
#
# c:\Users\annal\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# c:\Users\annal\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ...

# %%
# merge OHLC with WRDS

ohlc.merge(wrds, left_on = 'ppln_cusip', right_on = 'cusip')
# Out:
#             index    datadate  prcod  prchd    prcld  prccd    cusip_x  \
# 0              38  2023-02-01  45.00  47.22  41.6300  43.72  344849104
# 1              38  2023-02-01  45.00  47.22  41.6300  43.72  344849104
# 2              38  2023-02-01  45.00  47.22  41.6300  43.72  344849104
# 3              38  2023-02-01  45.00  47.22  41.6300  43.72  344849104
# 4              38  2023-02-01  45.00  47.22  41.6300  43.72  344849104
# ...           ...         ...    ...    ...      ...    ...        ...
# 28450857  1001439  2023-03-01  17.15  17.35  13.4035  13.82  360271100
# 28450858  1001439  2023-03-01  17.15  17.35  13.4035  13.82  360271100
# 28450859  1001439  2023-03-01  17.15  17.35  13.4035  13.82  360271100
# 28450860  1001439  2023-03-01  17.15  17.35  13.4035  13.82  360271100
# 28450861  1001439  2023-03-01  17.15  17.35  13.4035  13.82  360271100
#
#          ppln_cusip  gvkey  permno  ... sale_nwc rd_sale adv_sale  staff_sale  \
# ...

# %%
ohlc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001510 entries, 0 to 1001509
# Data columns (total 8 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   index       1001510 non-null  int64
#  1   datadate    1001510 non-null  object
#  2   prcod       1001510 non-null  float64
#  3   prchd       1001510 non-null  float64
#  4   prcld       1001510 non-null  float64
#  5   prccd       1001510 non-null  float64
#  6   cusip       1001510 non-null  object
#  7   ppln_cusip  1001510 non-null  object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 61.1+ MB
